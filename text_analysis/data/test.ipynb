# %%
import json
import pandas as pd

# %%
data = []
with open('yelp_academic_dataset_user.json', 'r', encoding='utf-8') as f:
    for line in f:
        data.append(json.loads(line))

df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %%
df.head()['elite']
# Out:
# 0    2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 1    2006,2007,2008,2009,2010,2011,2012,2013,2014,2...
# 2                                       2009,2010,2011
# 3                                                 2010
# 4
# Name: elite, dtype: object

# %%
df = df[['user_id', 'friends']]
df.to_excel('yelp_academic_dataset_user.xlsx', index=False)

# %%
import pandas as pd

print(pd.read_excel('yelp_academic_dataset_user.xlsx'))
# Out:
#                        user_id  \
# 0       j14WgRoU_-2ZE1aw1dXrJg
# 1       NIhcRW6DWvk1JQhDhXwgOQ
# 2       IpLRJY4CP3fXtlEd8Y4GFQ
# 3       N4Y2GiUxnQOvUUHtFyayKg
# 4       LwZJFLGxQwjjeOgpqTJnfw
# ...                        ...
# 207747  5Npu-zF5txhTFA9kX9ZtfA
# 207748  sOFXDmWpvOO0-TPXAmElRg
# 207749  PCYHtGj3x5gp-Bgc__g43g
# 207750  VkDSIM_-Allc9dG1tAhe_w
# 207751  fB3jbHi3m0L2KgGOxBv6uw
#
#                                                   friends
# 0       ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...
# 1       T1upaPMzuW7pNj74fO1rjA, CP28puvAEimt4ziuGTDaHA...
# 2       hdwDo7CLh9aN_9PckAos4Q, ci-mepWGgsgGT3sFI2mhMg...
# 3       nLxx0ZC9ni7ifnjsXLonSQ, ium_dLWZUn7N-FUwXTgHUA...
# 4       RHsmgIvCfnFL7DPNptKY8A, mObXpXBnaOV_UhE0gWwvPQ...
# ...                                                   ...
# 207747                                                NaN
# 207748                                                NaN
# ...
